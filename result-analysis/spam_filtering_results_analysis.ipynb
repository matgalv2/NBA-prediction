# %%
import pandas as pd

# %%
result = pd.read_csv("X:/ProgramFiles/JetBrains/PycharmProjects/NBA-predictor/resources/researches/spam-filtering-lgr.tsv", sep="\t")

# %%
result
# Out:
#          technique        C regularization           solver  accuracy
# 0    lemmatization  1000.00             l1             saga   0.94325
# 1    lemmatization  1000.00             l1        liblinear   0.93866
# 2    lemmatization   100.00             l1             saga   0.94325
# 3    lemmatization   100.00             l1        liblinear   0.94786
# 4    lemmatization    50.00             l1             saga   0.94428
# ..             ...      ...            ...              ...       ...
# 107       stemming     0.01             l2        liblinear   0.91159
# 108       stemming     0.01             l2        newton-cg   0.89576
# 109       stemming     0.01             l2  newton-cholesky   0.89576
# 110       stemming     0.01             l2              sag   0.89883
# 111       stemming     0.01             l2             saga   0.91006
#
# [112 rows x 5 columns]

# %%
result_nba = pd.read_csv("X:/ProgramFiles/JetBrains/PycharmProjects/NBA-predictor/resources/researches/spam-filtering-comments-lgr.tsv", sep="\t")
result_nba
# Out:
#          technique        C regularization           solver  accuracy
# 0    lemmatization  1000.00             l1             saga   0.97886
# 1    lemmatization  1000.00             l1        liblinear   0.96841
# 2    lemmatization   100.00             l1             saga   0.97886
# 3    lemmatization   100.00             l1        liblinear   0.97329
# 4    lemmatization    50.00             l1             saga   0.97900
# ..             ...      ...            ...              ...       ...
# 107       stemming     0.01             l2        liblinear   0.95053
# 108       stemming     0.01             l2        newton-cg   0.94983
# 109       stemming     0.01             l2  newton-cholesky   0.94983
# 110       stemming     0.01             l2              sag   0.94988
# 111       stemming     0.01             l2             saga   0.94997
#
# [112 rows x 5 columns]
