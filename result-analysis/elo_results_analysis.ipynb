# %%
import pandas as pd

# %%
result = pd.read_csv("X:/ProgramFiles/JetBrains/PycharmProjects/NBA-predictor/resources/researches/elo_parameters.tsv", sep="\t")

# %%
result.sort_values(by=["accuracy"], ascending=False)
# Out:
#      Basic ELO  k0  lambda  accuracy  precision  recall      f1  roc_auc
# 669       1300   6     0.6    0.6342     0.6466  0.6978  0.6688   0.6855
# 192        700   8     0.6    0.6341     0.6470  0.6949  0.6678   0.6851
# 102        600   6     0.6    0.6338     0.6466  0.6962  0.6679   0.6855
# 183        700   6     0.6    0.6338     0.6461  0.6978  0.6684   0.6854
# 507       1100   6     0.6    0.6338     0.6461  0.6983  0.6687   0.6856
# ..         ...  ..     ...       ...        ...     ...     ...      ...
# 458       1000  12     1.6    0.5896     0.5983  0.7002  0.6441   0.6223
# 557       1100  16     1.6    0.5896     0.5990  0.6951  0.6424   0.6260
# 233        700  16     1.6    0.5886     0.5975  0.6988  0.6432   0.6244
# 71         500  16     1.6    0.5885     0.5978  0.6919  0.6405   0.6245
# 890       1500  18     1.6    0.5878     0.5972  0.6935  0.6409   0.6215
#
# [1054 rows x 8 columns]
